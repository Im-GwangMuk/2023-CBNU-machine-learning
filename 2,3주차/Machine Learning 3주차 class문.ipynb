# %% [markdown]
# ## 클래스(class)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 위 내용을 우리가 앞에서 익힌 함수를 이용해 구현해 보자. 계산의 "더하기" 기능을 구현한 파이썬 코드는 다음과 같다.

# %%
result = 0

def add(num):
    global result
    result += num
    return result

print(add(3))
print(add(4))
# Out:
# 3
# 7

# %% [markdown]
# 그런데 만일 한 프로그램에서 2대의 계산기가 필요한 상황이 발생하면 어떻게 해야 할까? 각 계산기는 각각의 결괏값을 유지해야 하기 때문에 위와 같이 add 함수 하나만으로는 결괏값을 따로 유지할 수 없다.

# %%
result1 = 0
result2 = 0

def add1(num):
    global result1
    result1 += num
    return result1

def add2(num):
    global result2
    result2 += num
    return result2

print(add1(3))
print(add1(4))
print(add2(3))
print(add2(7))
# Out:
# 3
# 7
# 3
# 10

# %% [markdown]
# 위와 같은 경우에 클래스를 사용하면 다음과 같이 간단하게 해결할 수 있다.

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def add(self, num):
        self.result += num
        return self.result

# %%
cal1 = Calculator()
cal2 = Calculator()

# %%
print(cal1.add(3))
print(cal1.add(4))
print(cal2.add(3))
print(cal2.add(7))
# Out:
# 3
# 7
# 3
# 10

# %% [markdown]
# ## Class의 용어 정리

# %% [markdown]
# -  부모 클래스(Super Class)
#   - 모태가 되는 클래스
# - 자식 클래스(Sub Class, Child Class)
#   - 부모로 부터 상속 받은 클래스
# - 생성자(Constructor)
#   - 클래스 인스턴스를 생성
# - __init__() 메서드
#   - 클래스 생성자 메서드
# - 클래스 변수
#   - 클래스에서 공유 되는 변수
# - 메서드(Method)
# - 메서드 오버라이딩(Method Overriding)
#   - 상속 받은 메서드를 재정의

# %%
class Person :
  """Super Class"""
  total_count = 0                # 클래스 변수 : 클래스에서 공유되는 변수

  def __init_(self) :           # 생성자 메서드
    self.name = "홍길동"
    self.age = 3
    Person.total_count += 1


  def introduce(self) :          # 메서드
    print("제 이름은 {}이고, 나이는 {}살 입니다.".format(self.name, self.age))

# %%
P1 = Person()

# %%
P1.introduce()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-8575a7703372> in <module>()
# ----> 1 P1.introduce()
#
# <ipython-input-4-49925a08797c> in introduce(self)
#      10
#      11   def introduce(self) :          # 메서드
# ---> 12     print("제 이름은 {}이고, 나이는 {}살 입니다.".format(self.name, self.age))
#
# AttributeError: 'Person' object has no attribute 'name'

# %%
class Student(Person):
  """Sub Class"""

  def __init_(self):
    super().__init__()

# %%
student  = Student()
student.introduce()
# Out:
# 제 이름은 홍길동이고, 나이는 3살 입니다.

# %%
p1 = Person()
p2 = Person()
p3 = Person()

# %%
p2 = Person()
p2.introduce()
# Out:
# 제 이름은 홍길동이고, 나이는 3살 입니다.

# %%
p3 = Person()
p3.introduce()
# Out:
# 제 이름은 홍길동이고, 나이는 3살 입니다.

# %%
print(P1.__class__.total_count)
# print(p2.__class__.total_count)
# Out:
# 2

# %%
class Person :
  """Super Class"""
  total_count = 0                # 클래스 변수 : 클래스에서 공유되는 변수

  def __init__(self, name, age) :           # 생성자 메서드
    self.name = name
    self.age = age
    Person.total_count += 1


  def introduce(self) :          # 메서드
    print("제 이름은 {}이고, 나이는 {}살 입니다.".format(self.name, self.age))

# %%
p5 = Person("홍길동" ,27)
p5.introduce()
# Out:
# 제 이름은 홍길동이고, 나이는 27살 입니다.

# %% [markdown]
# ### **상속**

# %%
class Person :
  """Super Class"""
  total_count = 0                # 클래스 변수 : 클래스에서 공유되는 변수

  def __init__(self, name, age) :           # 생성자 메서드
    self.name = name
    self.age = age
    Person.total_count += 1

  def introduce(self) :          # 메서드
    print("제 이름은 {}이고, 나이는 {}살 입니다.".format(self.name, self.age))

class Student(Person):
  """Sub Class"""

  def __init__(self):
    super().__init__()

# %%
s1 = Student("홍길동",27)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-d42d17364939> in <module>()
# ----> 1 s1 = Student("홍길동",27)
#
# TypeError: __init__() takes 1 positional argument but 3 were given

# %%
class Student(Person):
  """Sub Class"""

  def __init__(self):
    super().__init__("홍길동", 27)

# %%
s2 = Student()

# %%
s2.introduce()
# Out:
# 제 이름은 홍길동이고, 나이는 27살 입니다.

# %%
class Student(Person):
  """Sub Class"""

  def __init__(self,name,age):
    super().__init__(name, age)

# %%
s3 = Student("홍길동", 50)

# %%
s3.introduce()
# Out:
# 제 이름은 홍길동이고, 나이는 50살 입니다.

# %%
# 상속 구조 확인

Student.mro()   # 현재 class, 상속 받은 class, object
# Out:
# [__main__.Student, __main__.Person, object]

# %%
Person.mro()
# Out:
# [__main__.Person, object]

# %% [markdown]
#  ## **클래스 메서드 오버라이딩**

# %%
class Person :
  """Super Class"""
  total_count = 0                # 클래스 변수 : 클래스에서 공유되는 변수

  def __init__(self, name="홍길동", age=20) :           # 생성자 메서드
    self.name = name
    self.age = age
    Person.total_count += 1


  def introduce(self) :          # 메서드
    print("제 이름은 {}이고, 나이는 {}살 입니다.".format(self.name, self.age))

class Student(Person):
  """Sub Class"""

  def __init__(self):
    super().__init__() 

  def introduce(self):
    super().introduce() #주석 이용시 자식 class의 내용만 호출
    print(f'난 Student야 내 이름은 {self.name}이고, 나이는 비밀이야.')
  
  # def print_age(self):
  #   print(f'내 나이는 {self.name}살.')

# %%
s1 = Student()
s1.introduce()
# Out:
# 제 이름은 홍길동이고, 나이는 20살 입니다.
# 난 Student야 내 이름은 홍길동이고, 나이는 비밀이야.

# %% [markdown]
# ## **상속 구조 확인**

# %%
Student.mro()
# Out:
# [__main__.Student, __main__.Person, object]

# %%
Person.mro()
# Out:
# [__main__.Person, object]
