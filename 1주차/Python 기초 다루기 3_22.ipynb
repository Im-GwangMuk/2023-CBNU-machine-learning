# %% [markdown]
# ## 1.1 기본 단축기

# %% [markdown]
# - 코드 셀 위에 삽입 Ctrl + M A

# %%
# Out:
# [1, 2, 3]

# %% [markdown]
# - 코드 셀 아래 삽입 Ctrl + M B

# %%
# Out:
# [1, 2, 3]

# %% [markdown]
# - 셀 지우기 Ctrl + M D

# %% [markdown]
# - 코드 셀로 변경 Ctrl+M Y

# %% [markdown]
# - 마크다운 셀로변경 Ctrl+M M

# %% [markdown]
# - 실행 취소 Ctrl + M Z

# %% [markdown]
# - help 문

# %%
# ?dir()
# Out:
# Object `dir()` not found.

# %% [markdown]
# - dir()

# %%
a = [1,2,3]

# %%
b = [1,2,3,4]

# %%
b
# Out:
# [1, 2, 3, 4]

# %%
dir()
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
a.append(3)

# %%
a
# Out:
# [1, 2, 3, 3]

# %% [markdown]
# # 1.2 인덱싱(Indexing), 슬라이싱(Slicing), 포매팅(formeting)

# %% [markdown]
# #### 인덱싱

# %%
string = 'Hello World'

# %%
string[0]
# Out:
# 'H'

# %%
string[5]
# Out:
# ' '

# %% [markdown]
# #### 슬라이싱

# %%
string[0:5]
# Out:
# 'Hello'

# %%
len(b)
# Out:
# 4

# %%
b[0]
# Out:
# 1

# %% [markdown]
# len

# %%
len(string)
# Out:
# 11

# %% [markdown]
# #### 포매팅

# %% [markdown]
# - %s 문자열
# - %d 정수
# - %f 실수

# %%
"My name is %s" %"홍길동"
# Out:
# 'My name is 홍길동'

# %%
input = ['철수','영희']

# %%
"My name is %s" % input[0]
# Out:
# 'My name is 철수'

# %%
name = '철수'
age = 20
print(f'나의 이름은 {name} 이고 나이는 {age} 입니다.')
# Out:
# 나의 이름은 철수 이고 나이는 20 입니다.

# %% [markdown]
# # 1.3 모듈 불러오기

# %% [markdown]
# #### import 모듈

# %% [markdown]
# - 모듈.변수
# - 모듈.함수()
# - 모듈.클래스()

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# #### import 모듈 as 이름

# %%
import math as m

# %%
m.pi
# Out:
# 3.141592653589793

# %% [markdown]
# #### from 모듈 import 변수(함수, 클래스)

# %%
from math import pi

# %%
pi
# Out:
# 3.141592653589793

# %% [markdown]
# # 1.4 튜플, 리스트와 배열(array)

# %% [markdown]
# #### 튜플

# %%
tu = (1,2,3)
tu[0] = 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-128ad7c1f91d> in <module>()
#       1 tu = (1,2,3)
# ----> 2 tu[0] = 3
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #### 리스트

# %%
list =[1,2,3]

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
list.append(1)

# %%
list.append([1,2])

# %%
list[4][1]
# Out:
# 2

# %%
list_2 = [1,2,3,4,5]

# %%
list_2.reverse()

# %%
list_2
# Out:
# [1, 2, 3, 4, 5]

# %%
list_2.index(5)
# Out:
# 4

# %%
list_2.pop(0)
# Out:
# 1

# %%
list_2
# Out:
# [2, 3, 4, 5]

# %% [markdown]
# #### 배열(array)

# %%
import numpy as np

np.zeros((2,2))
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
list_3 = [1,2,3,4]

# %%
dir(np.array(list_3))
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_function__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lshift__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__xor__',
#  'all',
#  'any',
#  'argmax',
#  'argmin',
#  'argpartition',
#  'argsort',
#  'astype',
#  'base',
#  'byteswap',
#  'choose',
#  'clip',
#  'compress',
#  'conj',
#  'conjugate',
#  'copy',
#  'ctypes',
#  'cumprod',
#  'cumsum',
#  'data',
#  'diagonal',
#  'dot',
#  'dtype',
#  'dump',
#  'dumps',
#  'fill',
#  'flags',
#  'flat',
#  'flatten',
#  'getfield',
#  'imag',
#  'item',
#  'itemset',
#  'itemsize',
#  'max',
#  'mean',
#  'min',
#  'nbytes',
#  'ndim',
#  'newbyteorder',
#  'nonzero',
#  'partition',
#  'prod',
#  'ptp',
#  'put',
#  'ravel',
#  'real',
#  'repeat',
#  'reshape',
#  'resize',
#  'round',
#  'searchsorted',
#  'setfield',
#  'setflags',
#  'shape',
#  'size',
#  'sort',
#  'squeeze',
#  'std',
#  'strides',
#  'sum',
#  'swapaxes',
#  'take',
#  'tobytes',
#  'tofile',
#  'tolist',
#  'tostring',
#  'trace',
#  'transpose',
#  'var',
#  'view']

# %%
np.array(list_3).ndim
# Out:
# 1

# %%
np.zeros((3,3)).shape
# Out:
# (3, 3)

# %%
np.zeros((3,3,3)).ndim
# Out:
# 3

# %%
arr1 = np.array(list_3)

# %%
arr1.shape
# Out:
# (4,)

# %% [markdown]
# # 1.5 기타 제어 흐름 도구

# %% [markdown]
# #### if문

# %%
score = int(input("점수를 입력해 주세요(1~100) :  "))
# Out:
# 점수를 입력해 주세요(1~100) :  85

# %%
if score >= 90:
  print("A등급")
elif score >= 80 and score <90:
  print("B등급")
elif score >= 70 and score < 80:
  print("C등급")
else:
  print("D등급")
# Out:
# B등급

# %% [markdown]
# #### for문

# %%
cnt= 0
for i in range(11):
  cnt+=i #cnt = cnt +i
print(cnt)
# Out:
# 55

# %% [markdown]
# #### while문

# %%
cnt = 0
i= 1
while i <11:
  cnt+=i #cnt =cnt+i
  i = i+1
print(cnt)
# Out:
# 55

# %% [markdown]
# ## 연습문제

# %%
num_list=[1,2,3,4,5]
num_list.reverse()

# %%
num_list
# Out:
# [5, 4, 3, 2, 1]

# %%
exam_list = [1,'abc',[2,'de'],5]
exam_list[2][1][1]
# Out:
# 'e'

# %%
Word ='가나다'
empty_list=[]
for i in Word:
  empty_list.append(i*2)
empty_list
# Out:
# ['가가', '나나', '다다']

# %%
Ice = ['메로나','월드콘','빵빠레']
Ice.extend(['죠스바','폴라포'])
Ice
# Out:
# ['메로나', '월드콘', '빵빠레', '죠스바', '폴라포']

# %%
list(range(5,10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-31644a7176d0> in <module>()
# ----> 1 list(range(5,10))
#
# TypeError: 'list' object is not callable

# %%
list(range(10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-1e702c11e83e> in <module>()
# ----> 1 list(range(10))
#
# TypeError: 'list' object is not callable

# %% [markdown]
# ## 1.6 함수 정의하기

# %%
def plus(A,B):
  print(A+B)

# %%
plus(1,2)
# Out:
# 3

# %%
def minus(A,B):
  print(A-B)

# %%
minus(2,1)
# Out:
# 1

# %%
def a():
  pass

# %%
a()
